# %% [markdown]
# # Кейс 1. MLP для многоклассовой классификации (Default of Credit Card Clients) — стартовый ноутбук
#
# Заготовка к [kim-01-mlp-multiclass.md](../kim-01-mlp-multiclass.md): полное условие, критерии, рубрика и правила использования генеративного ИИ — в тексте КИМ.
#
# **Как работать:** выполняйте разделы по порядку, заменяя `TODO` собственным кодом. Ячейки с проверками должны выполняться без ошибок. Установка окружения: `pip install -r requirements.txt` (см. корень репозитория), подробности — `docs/reproducibility.md`.

# %% [markdown]
# ## Окружение

# %%
# Проверка окружения (должно выполняться без ошибок)
import sys, numpy as np, torch
print(f"Python:  {sys.version.split()[0]}  (требуется 3.10+)")
print(f"numpy:   {np.__version__}")
print(f"torch:   {torch.__version__}")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"device:  {device}  (работа возможна и на CPU — см. docs/reproducibility.md)")

# %% [markdown]
# ## Воспроизводимость

# %%
# Воспроизводимость: подставьте номер своего варианта
VARIANT = 1          # TODO: номер варианта
SEED = 30 + VARIANT  # базовый seed курса + вариант

import random, numpy as np
random.seed(SEED)
np.random.seed(SEED)
import torch
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# %% [markdown]
# ### Шаг 1. Загрузка и подготовка Default of Credit Card Clients

# %%
# Набор загружает scripts/download_data.py --uci (появится в data/uci_credit/)
import pandas as pd
from pathlib import Path
DATA = Path("../../data/uci_credit")  # путь от каталога attachments/
# TODO: pd.read_excel(DATA / "default_of_credit_card_clients.xls", header=1);
# предобработка, разбиение train/validation/test

# %% [markdown]
# ### Шаг 2. Несколько моделей MLP с разными гиперпараметрами

# %%
# TODO: слои/нейроны, активации, оптимизатор

# %% [markdown]
# ### Шаг 3. Метрики (Accuracy, Precision, Recall, F1 — макро/взвешенно)

# %%
# TODO: sklearn.metrics.classification_report

# %% [markdown]
# ### Шаг 4. Отчёт: гиперпараметры и метрики по каждой модели

# %%
# TODO: сводная таблица

# %% [markdown]
# ### Шаг 5. Выводы по выбору лучших моделей

# %%
# TODO: markdown-ячейка

# %% [markdown]
# ## Чек-лист перед сдачей
#
# - [ ] Все ячейки выполняются подряд (`Restart & Run All`) без ошибок
# - [ ] Указан номер варианта, seed соответствует варианту
# - [ ] Выводы записаны в markdown-ячейках
# - [ ] Соблюдены правила использования генеративного ИИ из КИМ
