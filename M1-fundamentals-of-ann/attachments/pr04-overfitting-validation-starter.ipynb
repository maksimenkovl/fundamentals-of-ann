# %% [markdown]
# # ПР 4. Диагностика переобучения, валидация, ROC-AUC — стартовый ноутбук
#
# Заготовка к [kim-04-overfitting-validation.md](../kim-04-overfitting-validation.md): полное условие, критерии, рубрика и правила использования генеративного ИИ — в тексте КИМ.
#
# **Как работать:** выполняйте разделы по порядку, заменяя `TODO` собственным кодом. Ячейки с проверками должны выполняться без ошибок. Установка окружения: `pip install -r requirements.txt` (см. корень репозитория), подробности — `docs/reproducibility.md`.

# %% [markdown]
# ## Окружение

# %%
# Проверка окружения (должно выполняться без ошибок)
import sys, numpy as np, matplotlib
print(f"Python:     {sys.version.split()[0]}  (требуется 3.10+)")
print(f"numpy:      {np.__version__}")
print(f"matplotlib: {matplotlib.__version__}")
import sklearn
print(f"sklearn:    {sklearn.__version__}")

# %% [markdown]
# ## Воспроизводимость

# %%
# Воспроизводимость: подставьте номер своего варианта
VARIANT = 1          # TODO: номер варианта
SEED = 30 + VARIANT  # базовый seed курса + вариант

import random, numpy as np
random.seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# ### Шаг 1. Генерация данных make_classification

# %%
from sklearn.datasets import make_classification
X, y = make_classification(n_samples=2000, n_features=20, random_state=SEED)

# %% [markdown]
# ### Шаг 2. Разбиение train / validation / test

# %%
from sklearn.model_selection import train_test_split
# TODO: 60/20/20 c random_state=SEED

# %% [markdown]
# ### Шаг 3. Сохранение состояния модели на лучшую эпоху

# %%
# TODO: функция чекпоинта — максимум Accuracy на validation,
# при равенстве — минимум Loss

# %% [markdown]
# ### Шаг 4. Визуализация: Loss/Accuracy по эпохам, ROC-кривые и AUC

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score
# TODO: графики train/validation; ROC для лучшей эпохи

# %% [markdown]
# ### Шаг 5. Финальные метрики (Accuracy train/val/test; ROC-AUC test)

# %%
# TODO: функция финальных метрик

# %% [markdown]
# ### Шаг 6. Несколько MLP: вывод о пере/недообучении

# %%
# TODO: обучите 2–3 конфигурации и прокомментируйте кривые

# %% [markdown]
# ### Шаг 7. Улучшение результата (lr, эпохи, нейроны)

# %%
# TODO

# %% [markdown]
# ### Шаг 8. Функции подбора оптимальных параметров с графиками

# %%
# TODO

# %% [markdown]
# ### Шаг 9. Сеть с оптимальными параметрами

# %%
# TODO: обучите финальную модель и выведите метрики

# %% [markdown]
# ## Чек-лист перед сдачей
#
# - [ ] Все ячейки выполняются подряд (`Restart & Run All`) без ошибок
# - [ ] Указан номер варианта, seed соответствует варианту
# - [ ] Выводы записаны в markdown-ячейках
# - [ ] Соблюдены правила использования генеративного ИИ из КИМ
