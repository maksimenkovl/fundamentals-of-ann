# %% [markdown]
# # ПР 3. Обучение ИНС (backpropagation) — стартовый ноутбук
#
# Заготовка к [kim-03-training.md](../kim-03-training.md): полное условие, критерии, рубрика и правила использования генеративного ИИ — в тексте КИМ.
#
# **Как работать:** выполняйте разделы по порядку, заменяя `TODO` собственным кодом. Ячейки с проверками должны выполняться без ошибок. Установка окружения: `pip install -r requirements.txt` (см. корень репозитория), подробности — `docs/reproducibility.md`.

# %% [markdown]
# ## Окружение

# %%
# Проверка окружения (должно выполняться без ошибок)
import sys, numpy as np, matplotlib
print(f"Python:     {sys.version.split()[0]}  (требуется 3.10+)")
print(f"numpy:      {np.__version__}")
print(f"matplotlib: {matplotlib.__version__}")

# %% [markdown]
# ## Воспроизводимость

# %%
# Воспроизводимость: подставьте номер своего варианта
VARIANT = 1          # TODO: номер варианта
SEED = 30 + VARIANT  # базовый seed курса + вариант

import random, numpy as np
random.seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# ### Шаг 1. Метод инициализации (размеры слоёв, learning rate)

# %%
class MLP:
    def __init__(self, n_input, n_hidden, n_output, learning_rate):
        self.lr = learning_rate
        # TODO: инициализация весов из [-1; 1]
        raise NotImplementedError

# %% [markdown]
# ### Шаг 2. Обучение с обновлением весов (ΔW_ho, ΔW_ih, MSE)

# %%
# TODO: train(X, Y): прямой проход из ПР 2 + расчёт дельт и обновление весов,
# накопление MSE по эпохе

# %% [markdown]
# ### Шаг 3. Обучение при 10, 1000, 100000 эпох

# %%
for epochs in (10, 1_000, 100_000):
    # TODO: обучите сеть на XOR, выведите итоговый MSE
    pass

# %% [markdown]
# ### Шаг 4. Метод проверки

# %%
# TODO: predict(X) без обновления весов

# %% [markdown]
# ### Шаг 5. Проверка на X_test

# %%
# TODO: создайте X_test и оцените качество

# %% [markdown]
# ### Шаг 6. Расширение X_test тремя случаями

# %%
# TODO: добавьте 3 новых случая и повторите проверку

# %% [markdown]
# ### Шаг 7. Дополнительно: модель 2-4-1 против 2-2-1

# %%
# TODO (по желанию): сравните точность архитектур 2-2-1 и 2-4-1

# %% [markdown]
# ## Чек-лист перед сдачей
#
# - [ ] Все ячейки выполняются подряд (`Restart & Run All`) без ошибок
# - [ ] Указан номер варианта, seed соответствует варианту
# - [ ] Выводы записаны в markdown-ячейках
# - [ ] Соблюдены правила использования генеративного ИИ из КИМ
