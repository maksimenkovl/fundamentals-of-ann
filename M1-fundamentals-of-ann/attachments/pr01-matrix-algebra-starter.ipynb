# %% [markdown]
# # ПР 1. Основы матричной алгебры на Python — стартовый ноутбук
#
# Заготовка к [kim-01-matrix-algebra.md](../kim-01-matrix-algebra.md): полное условие, критерии, рубрика и правила использования генеративного ИИ — в тексте КИМ.
#
# **Как работать:** выполняйте разделы по порядку, заменяя `TODO` собственным кодом. Ячейки с проверками должны выполняться без ошибок. Установка окружения: `pip install -r requirements.txt` (см. корень репозитория), подробности — `docs/reproducibility.md`.

# %% [markdown]
# ## Окружение

# %%
# Проверка окружения (должно выполняться без ошибок)
import sys, numpy as np, matplotlib
print(f"Python:     {sys.version.split()[0]}  (требуется 3.10+)")
print(f"numpy:      {np.__version__}")
print(f"matplotlib: {matplotlib.__version__}")

# %% [markdown]
# ## Воспроизводимость

# %%
# Воспроизводимость: подставьте номер своего варианта
VARIANT = 1          # TODO: номер варианта
SEED = 30 + VARIANT  # базовый seed курса + вариант

import random, numpy as np
random.seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# ### Шаг 1. Класс операций с матрицами (без готовых методов numpy)

# %%
class Matrix:
    """Операции над матрицами через циклы и списки (без numpy)."""

    def __init__(self, rows):
        self.rows = rows  # список списков

    def add(self, other):
        # TODO: поэлементное сложение
        raise NotImplementedError

    def scal_mul(self, k):
        # TODO: умножение на число
        raise NotImplementedError

    def matmul(self, other):
        # TODO: матричное умножение (тройной цикл)
        raise NotImplementedError

    def transpose(self):
        # TODO: транспонирование
        raise NotImplementedError

# %% [markdown]
# ### Шаг 2. Проверка на простых примерах вручную

# %%
A = Matrix([[1, 2], [3, 4]])
B = Matrix([[5, 6], [7, 8]])
# TODO: проверьте add, scal_mul, matmul, transpose и сравните с расчётом на бумаге

# %% [markdown]
# ### Шаг 3. Матрицы ≥10×10 через numpy.random.randint (seed — по варианту)

# %%
rng = np.random.default_rng(SEED)
M1 = rng.integers(0, 10, size=(10, 10))
M2 = rng.integers(0, 10, size=(10, 10))
print(M1[:3, :3])

# %% [markdown]
# ### Шаг 4. Применение методов своего класса к созданным матрицам

# %%
# TODO: оберните M1, M2 в Matrix (M1.tolist()) и выполните все операции

# %% [markdown]
# ### Шаг 5. Сверка с numpy

# %%
# TODO: сравните результаты своего класса с numpy (np.allclose)
# пример: assert np.allclose(np.array(result.rows), M1 + M2)

# %% [markdown]
# ## Чек-лист перед сдачей
#
# - [ ] Все ячейки выполняются подряд (`Restart & Run All`) без ошибок
# - [ ] Указан номер варианта, seed соответствует варианту
# - [ ] Выводы записаны в markdown-ячейках
# - [ ] Соблюдены правила использования генеративного ИИ из КИМ
