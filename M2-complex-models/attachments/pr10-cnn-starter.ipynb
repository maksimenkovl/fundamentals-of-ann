# %% [markdown]
# # ПР 10. CNN и transfer learning (ResNet-18) — стартовый ноутбук
#
# Заготовка к [kim-10-cnn.md](../kim-10-cnn.md): полное условие, критерии, рубрика и правила использования генеративного ИИ — в тексте КИМ.
#
# **Как работать:** выполняйте разделы по порядку, заменяя `TODO` собственным кодом. Ячейки с проверками должны выполняться без ошибок. Установка окружения: `pip install -r requirements.txt` (см. корень репозитория), подробности — `docs/reproducibility.md`.

# %% [markdown]
# ## Окружение

# %%
# Проверка окружения (должно выполняться без ошибок)
import sys, numpy as np, torch
print(f"Python:  {sys.version.split()[0]}  (требуется 3.10+)")
print(f"numpy:   {np.__version__}")
print(f"torch:   {torch.__version__}")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"device:  {device}  (работа возможна и на CPU — см. docs/reproducibility.md)")

# %% [markdown]
# ## Воспроизводимость

# %%
# Воспроизводимость: подставьте номер своего варианта
VARIANT = 1          # TODO: номер варианта
SEED = 30 + VARIANT  # базовый seed курса + вариант

import random, numpy as np
random.seed(SEED)
np.random.seed(SEED)
import torch
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# %% [markdown]
# ### Шаг 1. CNN для MNIST: 2 свёрточных слоя + классификатор

# %%
import torch.nn as nn

class SimpleCNN(nn.Module):
    def __init__(self, n_filters1=8, n_filters2=16, kernel_size=3):
        super().__init__()
        # TODO: Conv2d → ReLU → MaxPool2d ×2 + Linear
        # рассчитайте размерности карт признаков (числа — по варианту)
    def forward(self, x):
        raise NotImplementedError

# %% [markdown]
# ### Шаг 2. Обучение CNN (мини-батчи, Adam, регуляризация из ПР 7–8)

# %%
# TODO

# %% [markdown]
# ### Шаг 3. Сравнение с MLP из ПР 5 (качество, число параметров)

# %%
# Подсказка: sum(p.numel() for p in model.parameters())

# %% [markdown]
# ### Шаг 4. Повтор для CIFAR-10 (опционально SVHN)

# %%
# TODO

# %% [markdown]
# ### Шаг 5. Transfer learning: предобученная ResNet-18

# %%
from torchvision import models
resnet = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)
# TODO: заморозка всех слоёв, замена fc-классификатора, дообучение

# %% [markdown]
# ### Шаг 6. Полная vs частичная заморозка

# %%
# TODO

# %% [markdown]
# ### Шаг 7. Обучение «с нуля» vs дообучение

# %%
# TODO

# %% [markdown]
# ### Шаг 8. Сводный отчёт по всем моделям

# %%
# TODO: таблица + выводы

# %% [markdown]
# ## Чек-лист перед сдачей
#
# - [ ] Все ячейки выполняются подряд (`Restart & Run All`) без ошибок
# - [ ] Указан номер варианта, seed соответствует варианту
# - [ ] Выводы записаны в markdown-ячейках
# - [ ] Соблюдены правила использования генеративного ИИ из КИМ
