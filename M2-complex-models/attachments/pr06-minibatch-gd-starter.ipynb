# %% [markdown]
# # ПР 6. Mini-batch GD, Latency/Throughput — стартовый ноутбук
#
# Заготовка к [kim-06-minibatch-gd.md](../kim-06-minibatch-gd.md): полное условие, критерии, рубрика и правила использования генеративного ИИ — в тексте КИМ.
#
# **Как работать:** выполняйте разделы по порядку, заменяя `TODO` собственным кодом. Ячейки с проверками должны выполняться без ошибок. Установка окружения: `pip install -r requirements.txt` (см. корень репозитория), подробности — `docs/reproducibility.md`.

# %% [markdown]
# ## Окружение

# %%
# Проверка окружения (должно выполняться без ошибок)
import sys, numpy as np, torch
print(f"Python:  {sys.version.split()[0]}  (требуется 3.10+)")
print(f"numpy:   {np.__version__}")
print(f"torch:   {torch.__version__}")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"device:  {device}  (работа возможна и на CPU — см. docs/reproducibility.md)")

# %% [markdown]
# ## Воспроизводимость

# %%
# Воспроизводимость: подставьте номер своего варианта
VARIANT = 1          # TODO: номер варианта
SEED = 30 + VARIANT  # базовый seed курса + вариант

import random, numpy as np
random.seed(SEED)
np.random.seed(SEED)
import torch
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# %% [markdown]
# ### Шаг 1. Mini-batch градиентный спуск для MLP на MNIST

# %%
# TODO: обучение по мини-батчам при произвольном batch_size
# замер Latency (мс/батч) и Throughput (примеров/с) — time.perf_counter()

# %% [markdown]
# ### Шаг 2. Train/validation/test, визуализация, вывод о пере/недообучении

# %%
# TODO

# %% [markdown]
# ### Шаг 3. Модели с разными гиперпараметрами, графики accuracy

# %%
# TODO

# %% [markdown]
# ### Шаг 4. Оптимум в балансе accuracy / Throughput / Latency

# %%
# TODO: сводная таблица (lr, эпохи, нейроны, batch_size)

# %% [markdown]
# ### Шаг 5. Повтор для CIFAR-10 и SVHN

# %%
# TODO: наборы загружает scripts/download_data.py

# %% [markdown]
# ## Чек-лист перед сдачей
#
# - [ ] Все ячейки выполняются подряд (`Restart & Run All`) без ошибок
# - [ ] Указан номер варианта, seed соответствует варианту
# - [ ] Выводы записаны в markdown-ячейках
# - [ ] Соблюдены правила использования генеративного ИИ из КИМ
