# %% [markdown]
# # ПР 9. Алгоритмы оптимизации — стартовый ноутбук
#
# Заготовка к [kim-09-optimizers.md](../kim-09-optimizers.md): полное условие, критерии, рубрика и правила использования генеративного ИИ — в тексте КИМ.
#
# **Как работать:** выполняйте разделы по порядку, заменяя `TODO` собственным кодом. Ячейки с проверками должны выполняться без ошибок. Установка окружения: `pip install -r requirements.txt` (см. корень репозитория), подробности — `docs/reproducibility.md`.

# %% [markdown]
# ## Окружение

# %%
# Проверка окружения (должно выполняться без ошибок)
import sys, numpy as np, torch
print(f"Python:  {sys.version.split()[0]}  (требуется 3.10+)")
print(f"numpy:   {np.__version__}")
print(f"torch:   {torch.__version__}")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"device:  {device}  (работа возможна и на CPU — см. docs/reproducibility.md)")

# %% [markdown]
# ## Воспроизводимость

# %%
# Воспроизводимость: подставьте номер своего варианта
VARIANT = 1          # TODO: номер варианта
SEED = 30 + VARIANT  # базовый seed курса + вариант

import random, numpy as np
random.seed(SEED)
np.random.seed(SEED)
import torch
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# %% [markdown]
# ### Шаг 1. Momentum SGD вручную, сверка с torch.optim.SGD

# %%
# TODO: явный цикл обновления v = mu*v - lr*grad; w += v (без torch.optim),
# затем та же модель с torch.optim.SGD(momentum=...) — кривые должны совпасть

# %% [markdown]
# ### Шаг 2. Четыре оптимизатора при одинаковом lr, кривые Loss

# %%
# TODO: SGD, SGD+Momentum, RMSprop, Adam

# %% [markdown]
# ### Шаг 3. Оптимальный lr для каждого оптимизатора

# %%
# TODO

# %% [markdown]
# ### Шаг 4. Чувствительность lr → качество на validation

# %%
# TODO: график

# %% [markdown]
# ### Шаг 5. Сводная таблица (эпохи до порога, качество, время)

# %%
# TODO

# %% [markdown]
# ### Шаг 6. Дополнительно: разные размеры мини-батча

# %%
# TODO (по желанию)

# %% [markdown]
# ## Чек-лист перед сдачей
#
# - [ ] Все ячейки выполняются подряд (`Restart & Run All`) без ошибок
# - [ ] Указан номер варианта, seed соответствует варианту
# - [ ] Выводы записаны в markdown-ячейках
# - [ ] Соблюдены правила использования генеративного ИИ из КИМ
